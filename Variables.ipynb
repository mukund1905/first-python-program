# %%
x=10
type(x)
# Out:
# int

# %%
x="Python"
type(x)
# Out:
# str

# %%
x=True
type(x)
# Out:
# bool

# %%
### Data Type

# %%
y="Flase"
type(y)
# Out:
# str

# %% [markdown]
# # Variables

# %% [markdown]
# #### Variable name should not start with a number

# %%
2name="A","B"
2name
# Out:
#   Cell In[12], line 1
#     2name="A","B"
#     ^
# SyntaxError: invalid decimal literal

# %%
name="A","B"
name
# Out:
# ('A', 'B')

# %% [markdown]
# #### only allowed spetial character is under score

# %%
name-1="A","B"
name-1
# Out:
#   Cell In[14], line 1
#     name-1="A","B"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
name_list="A","B"
name_list
# Out:
# ('A', 'B')
