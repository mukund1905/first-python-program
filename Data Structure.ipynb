# %% [markdown]
# ### Day 2

# %% [markdown]
# ### Variables

# %% [markdown]
# ##### space is not allowed

# %%
namelist="Latha","prema"
namelist
# Out:
# ('Latha', 'prema')

# %%
name list="latha","prema"
name list
# Out:
#   Cell In[6], line 1
#     name list="latha","prema"
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Python is case_sensitive

# %% [markdown]
#  # Data Structure

# %% [markdown]
# ## List

# %% [markdown]
# ###### Elements in a list are seperated by comma and enclosed in square brackets

# %% [markdown]
# #### List is hetrogenous-> Multiple data type

# %% [markdown]
# #### list can have duplicates

# %%
sample_list=[1,2,3,4,-1,"hi",5.3,3,9,4]
sample_list
# Out:
# [1, 2, 3, 4, -1, 'hi', 5.3, 3, 9, 4]

# %%
type(sample_list)
# Out:
# list

# %%
sample_list[5]
# Out:
# 'hi'

# %%
sample_list[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sample_list[10]
#
# IndexError: list index out of range

# %%
sample_list[0]="hello"
sample_list
# Out:
# ['hello', 2, 3, 4, -1, 'hi', 5.3, 3, 9, 4]

# %% [markdown]
# ## Tuple

# %%
sample_tuple=(1,4,3.3,4.5,"hi")
sample_tuple
# Out:
# (1, 4, 3.3, 4.5, 'hi')

# %%
type(sample_tuple)
# Out:
# tuple

# %% [markdown]
# #### can or can not be in any kind of brackets

# %%
sample_tuple2=1,2,3,5.3,"hi"
sample_tuple2
# Out:
# (1, 2, 3, 5.3, 'hi')

# %%
sample_tuple[0]
# Out:
# 1

# %% [markdown]
# #### it is Immutable-> cannot be changed

# %%
sample_tuple[0]=100
sample_tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 sample_tuple[0]=100
#       2 sample_tuple
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Dictionary

# %% [markdown]
# #### 1) Key-value pair

# %% [markdown]
# #### 2) {}

# %% [markdown]
# #### 3) Indexing-Square bracket

# %% [markdown]
# #### 4) Mutable

# %%
dict_1={'name':"Arun","hobbies":["painting","singing","cooking"],1:23}

# %%
dict_1
# Out:
# {'name': 'Arun', 'hobbies': ['painting', 'singing', 'cooking'], 1: 23}

# %%
dict_1[keys]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 dict_1[keys]
#
# NameError: name 'keys' is not defined

# %%
dict_1.keys()
# Out:
# dict_keys(['name', 'hobbies', 1])

# %%
dict_1.values()
# Out:
# dict_values(['Arun', ['painting', 'singing', 'cooking'], 23])

# %%
dict_1['name']="Mukund"
dict_1
# Out:
# {'name': 'Mukund', 'hobbies': ['painting', 'singing', 'cooking'], 1: 23}

# %%
dict_1['hobbies']=['Badminton','table tennis']
dict_1
# Out:
# {'name': 'Mukund', 'hobbies': ['Badminton', 'table tennis'], 1: 23}

# %% [markdown]
# ### Set

# %% [markdown]
# ##### Does not allows duplicates

# %% [markdown]
# ##### Set does not allow duplicates

# %%
sample_set={1,2,3,4,5,1,23.3,3.4,"hi","hello","ds",-1,33.5,53.3}
sample_set
# Out:
# {-1, 1, 2, 23.3, 3, 3.4, 33.5, 4, 5, 53.3, 'ds', 'hello', 'hi'}

# %%
sample_set.add(100)
sample_set
# Out:
# {-1, 1, 100, 2, 23.3, 3, 3.4, 33.5, 4, 5, 53.3, 'ds', 'hello', 'hi'}

# %%
sample_set.remove(-1)
sample_set
# Out:
# {1, 100, 2, 23.3, 3, 3.4, 33.5, 4, 5, 53.3, 'ds', 'hello', 'hi'}
