# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Pandas Dataframe and Indexing

# %%
sports1=pd.Series([1,2,3,4],index=['cricket','football','basketball','golf'])
sports1
# Out:
# cricket       1
# football      2
# basketball    3
# golf          4
# dtype: int64

# %%
sports1['football']
# Out:
# 2

# %%
sports2=pd.Series([11,2,3,4],index=['cricket','football','baseball','golf'])
sports2
# Out:
# cricket     11
# football     2
# baseball     3
# golf         4
# dtype: int64

# %%
sports1+sports2
# Out:
# baseball       NaN
# basketball     NaN
# cricket       12.0
# football       4.0
# golf           8.0
# dtype: float64

# %%
df1=pd.DataFrame(np.random.rand(8,5),index='A B C D E F G H'.split(),columns='Score1 Score2 Score3 Score4 Score5'.split())
df1
# Out:
#      Score1    Score2    Score3    Score4    Score5
# A  0.973413  0.232670  0.796476  0.901416  0.960511
# B  0.484859  0.233468  0.154419  0.133543  0.293021
# C  0.015519  0.615446  0.229605  0.460556  0.008486
# D  0.975716  0.803414  0.692765  0.049644  0.812040
# E  0.362397  0.822423  0.320387  0.180053  0.626716
# F  0.586806  0.294748  0.113851  0.250750  0.630310
# G  0.125843  0.737709  0.996930  0.848911  0.391484
# H  0.263156  0.998083  0.178112  0.731967  0.677949

# %%
df1["Score1"]
# Out:
# A    0.973413
# B    0.484859
# C    0.015519
# D    0.975716
# E    0.362397
# F    0.586806
# G    0.125843
# H    0.263156
# Name: Score1, dtype: float64

# %%
df1[["Score1","Score2"]]
# Out:
#      Score1    Score2
# A  0.973413  0.232670
# B  0.484859  0.233468
# C  0.015519  0.615446
# D  0.975716  0.803414
# E  0.362397  0.822423
# F  0.586806  0.294748
# G  0.125843  0.737709
# H  0.263156  0.998083

# %%
df1['Score6']=df1['Score1']+df1['Score2']
df1
# Out:
#      Score1    Score2    Score3    Score4    Score5    Score6
# A  0.973413  0.232670  0.796476  0.901416  0.960511  1.206083
# B  0.484859  0.233468  0.154419  0.133543  0.293021  0.718328
# C  0.015519  0.615446  0.229605  0.460556  0.008486  0.630964
# D  0.975716  0.803414  0.692765  0.049644  0.812040  1.779130
# E  0.362397  0.822423  0.320387  0.180053  0.626716  1.184820
# F  0.586806  0.294748  0.113851  0.250750  0.630310  0.881554
# G  0.125843  0.737709  0.996930  0.848911  0.391484  0.863552
# H  0.263156  0.998083  0.178112  0.731967  0.677949  1.261238

# %%
df2={'ID':['01','02','03','04','05'],'Name':['Mukund','Tejash','Krish','Jitu','Riya'],'Profit':[23,34,54,64,73]}
df=pd.DataFrame(df2)
df
# Out:
#    ID    Name  Profit
# 0  01  Mukund      23
# 1  02  Tejash      34
# 2  03   Krish      54
# 3  04    Jitu      64
# 4  05    Riya      73

# %%
df["ID"]
# Out:
# 0    01
# 1    02
# 2    03
# 3    04
# 4    05
# Name: ID, dtype: object

# %%
df["Name"]
# Out:
# 0    Mukund
# 1    Tejash
# 2     Krish
# 3      Jitu
# 4      Riya
# Name: Name, dtype: object

# %%
df["Profit"]
# Out:
# 0    23
# 1    34
# 2    54
# 3    64
# 4    73
# Name: Profit, dtype: int64

# %%
df[["Name","Profit"]]
# Out:
#      Name  Profit
# 0  Mukund      23
# 1  Tejash      34
# 2   Krish      54
# 3    Jitu      64
# 4    Riya      73

# %%
df=df.drop("ID",axis=1)

# %%
df
# Out:
#      Name  Profit
# 0  Mukund      23
# 1  Tejash      34
# 2   Krish      54
# 3    Jitu      64
# 4    Riya      73

# %%
df.drop(3)
# Out:
#      Name  Profit
# 0  Mukund      23
# 1  Tejash      34
# 2   Krish      54
# 4    Riya      73
